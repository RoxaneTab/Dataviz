# %% [markdown]
# Graphe 1
# Réaliser un graphique avec deux axes. L'axe des abscisses va de 0 à 50 et s'intitule "Axe des x". L'axe des ordonnées s'intitule "Axe des y".
# Tracer la droite d'équation : x = 3y. Avec x allant de 0 à 50.
# Le graphe possède le titre suivant "Tracer une droite" et la droite est de couleur rouge.

# %%
import numpy as np

# %%
# importing the required module
import matplotlib.pyplot as plt

# x axis values
x = np.arange(0,50)
# corresponding y axis values
y = 3*x

# plotting the points
plt.plot(x, y, color='red', linestyle='dashed')

# setting x and y axis range
plt.ylim(0,150)
plt.xlim(0,50)

# naming the x axis
plt.xlabel('Axe des x')
# naming the y axis
plt.ylabel('Axe des y')

# giving a title to my graph
plt.title('Tracer une droite')

# function to show the plot
plt.show()

# %%
# import libraries
import pandas as pd
import numpy as np
import re
df = pd.read_csv('company_sales_data.csv')

# %%
# overview
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 0          1500        21100        211000
# 1          1200        18330        183300
# 2          1340        22470        224700
# 3          1130        22270        222700
# 4          1740        20960        209600
# 5          1555        20140        201400
# 6          1120        29550        295500
# 7          1400        36140        361400
# 8          1780        23400        234000
# 9          1890        26670        266700
# 10         2100        41280        412800
# 11         1760        30020        300200

# %% [markdown]
# Graphe 2
# En premier lieu, nous souhaitons un graphe qui donne la courbe du profit total réalisé chaque mois.

# %%
# axis values
df.plot(x="month_number", y="total_profit")

# plotting the points
plt.plot()

# setting x and y axis range
plt.ylim(0, 500000)
plt.xlim(1, 12)

# naming the x axis
plt.xlabel('Months')
# naming the y axis
plt.ylabel('Profit')

# giving a title to my graph
plt.title('Profit per month')

# function to show the plot
plt.show()

# %% [markdown]
# Graphe 3
# Ensuite, nous souhaitons un graphe qui donne la courbe de profit pour chaque produit, en fonction du temps.
# Chaque courbe aura une couleur différente et nous souhaitons une légende qui indique quelle couleur correspond à quel produit.

# %%
df.plot(x="month_number", y=["facecream", "facewash", "toothpaste", "bathingsoap", "shampoo", "moisturizer"])
plt.show()

# %% [markdown]
# Graphe 4
# Nous souhaitons un graphe qui compare, chaque mois, le nombre d'unités vendues pour chaque produit. A vous de choisir la meilleure représentation pour connaître le produit le plus vendu par mois.

# %%
df.drop(['total_profit', 'total_units'], axis=1 ).plot.bar('month_number')
# Out:
# <AxesSubplot:xlabel='month_number'>
